# %%
# %load_ext autoreload
# %autoreload 2

# %%
from money_tools import Rate
from datetime import datetime

# %%
rate = Rate(start_balance=100000,
                    annual_interest_rate=0.01,
                    monthly_payment=1000,
                    start_date=datetime(2019, 1, 1),
                    end_date=datetime(2019, 12, 31)
                    )

# %%
rate
# Out:
# Rate(start_balance=100000, annual_interest_rate=0.01, monthly_payment=1000, start_date='2019-01-01', end_date='2019-12-31')

# %%
r2 = Rate(start_balance=100000, annual_interest_rate=0.01, monthly_payment=1000, start_date='2019-01-01', end_date='2019-12-31')

# %%
r2.schedule.head()
# Out:
#         Date  Period  Begin Balance  Payment  Interest  Additional_Payment  \
# 0 2019-01-01       1      100000.00     1000      2.74                   0
# 1 2019-01-02       2       99002.74        0      2.71                   0
# 2 2019-01-03       3       99005.45        0      2.71                   0
# 3 2019-01-04       4       99008.16        0      2.71                   0
# 4 2019-01-05       5       99010.87        0      2.71                   0
#
#    End Balance
# 0     99002.74
# 1     99005.45
# 2     99008.16
# 3     99010.87
# 4     99013.58

# %%
rate.schedule
# Out:
#           Date  Period  Begin Balance  Payment  Interest  Additional_Payment  \
# 0   2019-01-01       1      100000.00     1000      2.74                   0
# 1   2019-01-02       2       99002.74        0      2.71                   0
# 2   2019-01-03       3       99005.45        0      2.71                   0
# 3   2019-01-04       4       99008.16        0      2.71                   0
# 4   2019-01-05       5       99010.87        0      2.71                   0
# 5   2019-01-06       6       99013.58        0      2.71                   0
# 6   2019-01-07       7       99016.29        0      2.71                   0
# 7   2019-01-08       8       99019.00        0      2.71                   0
# 8   2019-01-09       9       99021.71        0      2.71                   0
# 9   2019-01-10      10       99024.42        0      2.71                   0
# 10  2019-01-11      11       99027.13        0      2.71                   0
# ...
